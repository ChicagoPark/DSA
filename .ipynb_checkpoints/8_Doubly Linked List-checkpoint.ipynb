# %% [markdown]
# # Doubly Linked List

# %%
class Node():
    def __init__(self, value):
        self.value = value
        self.next = None
        self.prev = None

class doublyLinkedlist():
    def __init__(self):
        self.head = None
        self.tail = None
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
    
    # creation of doubly linked list
    def createDLL(self, nodeValue):
        node = Node(nodeValue)
        self.head = node
        self.tail = node
        return "The DLL is created Successfully"
    
    # insertion of doubly linked list
    def insertDLL(self, nodeValue, location):
        if self.head == None:
            print("The node cannot be inserted")
        else:
            newNode = Node(nodeValue)
            if location == 0:
                if self.head == self.tail:
                    newNode.next = self.head
                    self.tail.prev = newNode
                    self.head = newNode
                else:
                    newNode.next = self.head
                    self.head.prev = newNode
                    self.head = newNode

            elif location == -1:
                if self.head == self.tail:
                    newNode.prev = self.tail
                    self.tail.next = newNode
                    self.tail = newNode
                else:
                    newNode.prev = self.tail
                    self.tail.next = newNode
                    newNode = self.tail
            else:
                tempNode = self.head
                index = 0
                while index < location - 1:
                    tempNode = tempNode.next
                    index += 1
                newNode.next = tempNode.next
                newNode.prev = tempNode
                tempNode.next.prev = newNode
                tempNode.next = newNode

     
    #  traverse of doubly linked list
    def traverseDLL(self):
        if self.head == None:
            print("The node cannot be traversed")
        else:
            tempNode = self.head
            while tempNode:
                print(tempNode.value)
                tempNode = tempNode.next
                
    # reverse traversing doubly linked list
    def reverseDLL(self):
        if self.head == None:
            print("The node cannot be traversed")
        else:
            tempNode = self.tail
            while tempNode:
                print(tempNode.value)
                tempNode = tempNode.prev
                
    # search the element in doubly linked list
    def searchDLL(self, value):
        if self.head == None:
            print("linked list is empty")
        else:
            tempNode = self.head
            index = 0
            while tempNode:
                if tempNode.value == value:
                    print(f"index: {index}\nvalue: {tempNode.value}")
                    break
                tempNode = tempNode.next
                index += 1
            return "The node does not exist in this list"
        
    # delete the node in doubly linked list
    def deleteDLL(self, location):
        if self.head == None:
            print("linked list is empty")
        else:
            if location == 0:
                if self.head == self.tail:
                    self.head = None
                    self.tail = None
                else:
                    self.head = self.head.next
                    self.head.prev = None
                
            elif location == -1:
                if self.head == self.tail:
                    self.head = None
                    self.tail = None
                else:
                    tempNode = self.tail.prev
                    tempNode.next = None
                    self.tail = tempNode
            else:
                tempNode = self.head
                index = 0
                while index < location - 1:
                    index += 1
                    tempNode = tempNode.next
                tempNode.next = tempNode.next.next
                tempNode.next.prev = tempNode
            print("The node has been successully deleted")
            
    # delete the entire doubly linked list
    def deleteentireDLL(self):
        if self.head is None:
            print("There is not any node in DLL")
        else:
            tempNode = self.head
            #while tempNode:
            #    tempNode.prev = None
            #    tempNode = tempNode.next
            self.head = None
            self.tail = None
            print("The DLL has been successfully deleted")
        
doublyLL = doublyLinkedlist()
print(doublyLL.createDLL(5))

print([node.value for node in doublyLL])

print("----2. insert DLL ----")
doublyLL.insertDLL(0,0)
doublyLL.insertDLL(2,1)
doublyLL.insertDLL(6,2)
print([node.value for node in doublyLL])


print("----3. traverse DLL ----")
doublyLL.traverseDLL()
print([node.value for node in doublyLL])

print("----4. reverse traverse DLL ----")
doublyLL.reverseDLL()

print("----5. search the value in DLL ----")
doublyLL.searchDLL(2)

print("----6-1. delete the first node in DLL ----")
doublyLL.deleteDLL(0)
print([node.value for node in doublyLL])

print("----6-2. delete the certain value in DLL ----")
doublyLL.deleteDLL(1)
print([node.value for node in doublyLL])

print("----6-3. delete the last node in DLL ----")
doublyLL.deleteDLL(-1)
print([node.value for node in doublyLL])

print("----7. delete the entire node in DLL ----")
doublyLL.deleteentireDLL()
print([node.value for node in doublyLL])
# Out:
# The DLL is created Successfully
# [5]
# ----2. insert DLL ----
# [0, 2, 6, 5]
# ----3. traverse DLL ----
# 0
# 2
# 6
# 5
# [0, 2, 6, 5]
# ----4. reverse traverse DLL ----
# 5
# 6
# 2
# 0
# ----5. search the value in DLL ----
# index: 1
# value: 2
# ----6-1. delete the first node in DLL ----
# The node has been successully deleted
# [2, 6, 5]
# ----6-2. delete the certain value in DLL ----
# The node has been successully deleted
# [2, 5]
# ----6-3. delete the last node in DLL ----
# The node has been successully deleted
# [2]
# ----7. delete the entire node in DLL ----
# The DLL has been successfully deleted
# []
